# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import pprint
import time
from sklearn.cluster import KMeans
from pylab import rcParams
# %matplotlib inline

travel = pd.read_csv("./103年國人旅遊狀況調查/全年出國旅次.csv")
travel.head(200)
# Out:
#      vq23  vq23a  vq24_1 vq24_2 vq24_3 vq24_4 vq24_5 vq24_6  vq25 vq26a  \
# 0       3      2       3      .      .      .      .      .     1     2
# 1       4      3      12      .      .      .      .      .     2     .
# 2       7      6       2      .      .      .      .      .     2     .
# 3       6      5      12      .      .      .      .      .     1     3
# 4      15     14      12      .      .      .      .      .     2     .
# 5       6      5       2      .      .      .      .      .     2     .
# 6       5      4      12      .      .      .      .      .     1     3
# 7       6      5      12      .      .      .      .      .     1     3
# 8       7      6       2      .      .      .      .      .     1     3
# 9       6      5       2      .      .      .      .      .     2     .
# 10     30     29      32      .      .      .      .      .     4     .
# 11      7      6       2      .      .      .      .      .     2     .
# ...

# %%
travel.describe()
# Out:
#               vq23        vq23a       vq24_1         vq25         vq27  \
# count  2029.000000  2029.000000  2029.000000  2029.000000  2029.000000
# mean      8.263184     7.257270     8.981764     1.424840     2.182356
# std       9.302167     9.278661     7.203793     2.109875     1.193863
# min       2.000000     1.000000     1.000000     1.000000     1.000000
# 25%       5.000000     4.000000     2.000000     1.000000     1.000000
# 50%       5.000000     4.000000    12.000000     1.000000     2.000000
# 75%       8.000000     7.000000    12.000000     1.000000     3.000000
# max     120.000000   119.000000    37.000000    65.000000     4.000000
#
#                vb1          vb2          vb3          vb4          vb5  \
# count  2029.000000  2029.000000  2029.000000  2029.000000  2029.000000
# mean      6.567275     4.005914     7.631345     1.910301     5.534746
# std       1.981431     1.421505     4.274151     0.679974     2.906905
# ...
